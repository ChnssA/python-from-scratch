# %% [markdown]
# <a href="https://colab.research.google.com/github/ChnssA/python-from-scratch/blob/main/python_from_scratch_to_intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world
